# %% [markdown]
# <a href="https://colab.research.google.com/github/SOwens-Create/BabyPython/blob/master/QuizThree_AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/adult_data.csv')

# %%
df.info('adult_data.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
sns.histplot(data = df, x='age', bins=5)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data = df, x='salary', bins=2)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.histplot(data = df, x='sex', bins=2)
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
sns.boxplot(data=df, x='hours-per-week')
# Out:
# <Axes: xlabel='hours-per-week'>

# %%
sns.scatterplot(data=df, x='native-country', y='hours-per-week')
# Out:
# <Axes: xlabel='native-country', ylabel='hours-per-week'>

# %%
sns.scatterplot(data=df, x='hours-per-week', y='native-country')
# Out:
# <Axes: xlabel='hours-per-week', ylabel='native-country'>

# %%
sns.scatterplot(data=df, x='hours-per-week', y='occupation')
# Out:
# <Axes: xlabel='hours-per-week', ylabel='occupation'>

# %%
sns.boxplot(data=df, x='hours-per-week', y='occupation')
# Out:
# <Axes: xlabel='hours-per-week', ylabel='occupation'>

# %%
df.describe('capital-gain')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-b134811738eb> in <cell line: 1>()
# ----> 1 df.describe('capital-gain')
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10938         max            NaN      3.0
#   10939         """
# > 10940         return describe_ndframe(
#   10941             obj=self,
#   10942             include=include,
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/describe.py in describe_ndframe(obj, include, exclude, datetime_is_numeric, percentiles)
#      83     Dataframe or series description.
#      84     """
# ---> 85     percentiles = refine_percentiles(percentiles)
#      86
#      87     describer: NDFrameDescriberAbstract
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/describe.py in refine_percentiles(percentiles)
# ...

# %%
sns.histplot(data = df, x='capital-loss', bins=3)
# Out:
# <Axes: xlabel='capital-loss', ylabel='Count'>
